# %% [markdown]
# ### Explicación detallada del paso
# # Ejercicio 2
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %% [markdown]
# ### Explicación detallada del paso
# Ahora mismo se hará un análisis de los precios del combustible en colombia en el año 2023.
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %% [markdown]
# ### Explicación detallada del paso
# Importación de la Base de Datos
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %%
combustible_1 = pd.read_csv("datos/2023-1.csv")
combustible_2 = pd.read_csv("datos/2023-2.csv")
combustible_3 = pd.read_csv("datos/2023-3.csv")
combustible_4 = pd.read_csv("datos/2023-4.csv")

# %%
df_2023 = pd.concat([combustible_1, combustible_2, combustible_3, combustible_4], ignore_index=True)
df_2023.head(10)
# Out:
#   BANDERA                                  NOMBRE COMERCIAL        PRODUCTO  \
# 0  TERPEL       ESTACION DE SERVICIO SERVICENTRO LA PEDRERA          DIESEL
# 1  TERPEL       ESTACION DE SERVICIO SERVICENTRO LA PEDRERA  GASOLINA MOTOR
# 2  TERPEL                                   BALSA EL CONDOR  GASOLINA MOTOR
# 3  TERPEL                                   BALSA EL CONDOR          DIESEL
# 4  TERPEL  ESTACION DE SERVICIO DISTRIBUIDORA LOS COMUNEROS  GASOLINA MOTOR
# 5  TERPEL  ESTACION DE SERVICIO DISTRIBUIDORA LOS COMUNEROS  GASOLINA MOTOR
# 6  TERPEL  ESTACION DE SERVICIO DISTRIBUIDORA LOS COMUNEROS          DIESEL
# 7  TEXACO                             EDS COMDECOM ABRIAQUI  GASOLINA MOTOR
# 8  TEXACO                             EDS COMDECOM ABRIAQUI          DIESEL
# 9  TEXACO    ESTACIÓN DE SERVICIO Y MALL SANTA LUCIA S.A.S.          DIESEL
#
#   FECHA REGISTRO DEPARTAMENTO   MUNICIPIO  VALOR PRECIO
# 0    01-Jan-2023     AMAZONAS  LA PEDRERA       15000.0
# 1    01-Jan-2023     AMAZONAS  LA PEDRERA       15500.0
# 2    01-Jan-2023     AMAZONAS     LETICIA       11380.0
# 3    01-Jan-2023     AMAZONAS     LETICIA       10840.0
# 4    01-Jan-2023     AMAZONAS     LETICIA       11380.0
# 5    01-Jan-2023     AMAZONAS     LETICIA       11380.0
# 6    01-Jan-2023     AMAZONAS     LETICIA       10671.0
# 7    01-Jan-2023    ANTIOQUIA    ABRIAQUÍ       11870.0
# 8    01-Jan-2023    ANTIOQUIA    ABRIAQUÍ       10910.0
# 9    01-Jan-2023    ANTIOQUIA       AMAGÁ        9610.0

# %% [markdown]
# ### Explicación detallada del paso
# Al unir todos los trimestres del 2023 y guardarlos en un nuevo dataframe llamado 'df_2023', se obtiene un total de los registros de todos los precios de los combustibles en el país del año de 2023
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %%
df_2023.shape
# Out:
# (268017, 7)

# %%
df_2023.columns
# Out:
# Index(['BANDERA', 'NOMBRE COMERCIAL', 'PRODUCTO', 'FECHA REGISTRO',
#        'DEPARTAMENTO', 'MUNICIPIO', 'VALOR PRECIO'],
#       dtype='object')

# %%
df_2023.columns=["bandera", "nombreCo", "producto","fecha","depto","munic","valor"]

# %%
df_2023["bandera"].unique()
# Out:
# array(['TERPEL', 'TEXACO', 'PRIMAX', 'ZEUSS\xa0', 'BIOMAX',
#        'PETROMIL\xa0', 'ESSO', 'BRIO\xa0', 'PETROBRAS', 'PUMA',
#        'PLUS MAS', 'ECOS', 'OCTANO', 'AYATAWACOOP', 'DISCOWACOOP',
#        'COOMULPINORT', 'DISCOM', 'P Y B', 'PETRODECOL', 'PETRDECOL',
#        'SAVE', 'PROXXON', 'ZAPATA Y VELASQUEZ\xa0'], dtype=object)

# %%
len(df_2023["bandera"].unique())
# Out:
# 23

# %% [markdown]
# ### Explicación detallada del paso
# **Productos**
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %%
df_2023["producto"].value_counts()
# Out:
# producto
# GASOLINA MOTOR    127338
# DIESEL            108279
# EXTRA              32400
# Name: count, dtype: int64

# %% [markdown]
# ### Explicación detallada del paso
# ### **Filtrando por el tipo de producto**
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %% [markdown]
# ### Explicación detallada del paso
# Para poder hacer el estudio de cada uno de los tipos de combustibles filtremos nuestra base de datos.
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %%
gasolina=df_2023[df_2023["producto"]=="GASOLINA MOTOR"]
diesel =df_2023[df_2023["producto"]=="DIESEL"]
extra =df_2023[df_2023["producto"]=="EXTRA"]

# %%
gasolina.head()
# Out:
#   bandera                                          nombreCo        producto  \
# 1  TERPEL       ESTACION DE SERVICIO SERVICENTRO LA PEDRERA  GASOLINA MOTOR
# 2  TERPEL                                   BALSA EL CONDOR  GASOLINA MOTOR
# 4  TERPEL  ESTACION DE SERVICIO DISTRIBUIDORA LOS COMUNEROS  GASOLINA MOTOR
# 5  TERPEL  ESTACION DE SERVICIO DISTRIBUIDORA LOS COMUNEROS  GASOLINA MOTOR
# 7  TEXACO                             EDS COMDECOM ABRIAQUI  GASOLINA MOTOR
#
#          fecha      depto       munic    valor
# 1  01-Jan-2023   AMAZONAS  LA PEDRERA  15500.0
# 2  01-Jan-2023   AMAZONAS     LETICIA  11380.0
# 4  01-Jan-2023   AMAZONAS     LETICIA  11380.0
# 5  01-Jan-2023   AMAZONAS     LETICIA  11380.0
# 7  01-Jan-2023  ANTIOQUIA    ABRIAQUÍ  11870.0

# %%
diesel.head()
# Out:
#   bandera                                          nombreCo producto  \
# 0  TERPEL       ESTACION DE SERVICIO SERVICENTRO LA PEDRERA   DIESEL
# 3  TERPEL                                   BALSA EL CONDOR   DIESEL
# 6  TERPEL  ESTACION DE SERVICIO DISTRIBUIDORA LOS COMUNEROS   DIESEL
# 8  TEXACO                             EDS COMDECOM ABRIAQUI   DIESEL
# 9  TEXACO    ESTACIÓN DE SERVICIO Y MALL SANTA LUCIA S.A.S.   DIESEL
#
#          fecha      depto       munic    valor
# 0  01-Jan-2023   AMAZONAS  LA PEDRERA  15000.0
# 3  01-Jan-2023   AMAZONAS     LETICIA  10840.0
# 6  01-Jan-2023   AMAZONAS     LETICIA  10671.0
# 8  01-Jan-2023  ANTIOQUIA    ABRIAQUÍ  10910.0
# 9  01-Jan-2023  ANTIOQUIA       AMAGÁ   9610.0

# %%
extra.head()
# Out:
#    bandera                                   nombreCo producto        fecha  \
# 15  TERPEL              ESTACION DE SERVICIO POPALITO    EXTRA  01-Jan-2023
# 16  TERPEL  ESTACION DE SERVICIO PUERTAS DEL NORDESTE    EXTRA  01-Jan-2023
# 20  PRIMAX      ESTACION DE SERVICIO PRIMAX AUTOPISTA    EXTRA  01-Jan-2023
# 21  TERPEL                          TERPEL FONTIDUENO    EXTRA  01-Jan-2023
# 31  ZEUSS          ESTACION DE SERVICIO LA CRISTALINA    EXTRA  01-Jan-2023
#
#         depto     munic    valor
# 15  ANTIOQUIA   BARBOSA  18760.0
# 16  ANTIOQUIA   BARBOSA  19400.0
# 20  ANTIOQUIA     BELLO  19580.0
# 21  ANTIOQUIA     BELLO  20520.0
# 31  ANTIOQUIA  CISNEROS  20000.0

# %%
gasolina["valor"].describe()
# Out:
# count    1.273380e+05
# mean     1.262035e+04
# std      4.135571e+04
# min      1.000000e+00
# 25%      1.103000e+04
# 50%      1.254000e+04
# 75%      1.398000e+04
# max      1.475015e+07
# Name: valor, dtype: float64

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(8, 6))
ax = sns.boxplot(x='valor', data=gasolina, color="#3B89BD")

ax.set_xlabel("Valor Precio")
plt.title('Precio Gasolina')
plt.show()

# %%
print("Datos faltantes: ",gasolina["valor"].isna().sum())
# Out:
# Datos faltantes:  0

# %%
def detect_outliers_zscore(data):
    outliers = []
    thres = 3
    mean = np.mean(data)
    std = np.std(data)
    for idx, value in enumerate(data):
        z_score = (value - mean) / std
        if np.abs(z_score) > thres:
            outliers.append(idx)
    
    return outliers

# %%
out=detect_outliers_zscore(gasolina["valor"])
len(out)
# Out:
# 4

# %%
gasolina.iloc[out, gasolina.columns.get_loc('valor')] = np.nan

# %%
imp = IterativeImputer(max_iter=5, random_state=500)

# Imputar los datos faltantes
gasolina_imputado = gasolina.copy()
gasolina_imputado[['valor']] = imp.fit_transform(gasolina[['valor']])

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(8, 6))
ax = sns.boxplot(x='valor', data=gasolina_imputado, color="#3B89BD")

ax.set_xlabel("Valor Precio")
plt.title('Precio Gasolina')
plt.show()

# %% [markdown]
# ### Explicación detallada del paso
# Con esto se logró la imputación de los valores extremos del precio de la gasolina en 2023. Detectamos los valores atípicos utilizando los z-scores y realizamos la imputación con el método iterativo. La idea es aplicar este mismo proceso a los otros dos productos.
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %%
gas_bandera = gasolina_imputado.groupby('bandera')['valor'].mean().reset_index()
gas_bandera = gas_bandera.sort_values(by='valor',ascending=False)
gas_bandera=gas_bandera.head(12)

plt.figure(figsize=(12, 6))
sns.barplot(data=gas_bandera, x='bandera', y='valor', palette='viridis')
plt.xlabel('Bandera')
plt.ylabel('precio por bandera')
plt.xticks(rotation=90)
plt.tight_layout()

# %%
gas_bandera
# Out:
#                 bandera         valor
# 21  ZAPATA Y VELASQUEZ   16200.487903
# 8                OCTANO  15444.754954
# 5           DISCOWACOOP  13355.970158
# 4                DISCOM  13354.115337
# 9                 P Y B  13288.808000
# 16              PROXXON  13272.784810
# 0           AYATAWACOOP  13189.970560
# 14             PLUS MAS  13014.630485
# 22               ZEUSS   12928.796348
# 18                 SAVE  12790.250000
# 20               TEXACO  12639.409670
# 2                 BRIO   12592.724242

# %% [markdown]
# ### Explicación detallada del paso
# De la gráfica anterior,se muestran las 12 empresas distribuidoras de gasolina con los precios mas altos en colombia en el 2023. siendo "OCTANO" con el valor mas alto 15055.
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %% [markdown]
# ### Explicación detallada del paso
# #### ****Diesel****
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %%
diesel["valor"].describe()
# Out:
# count    108279.000000
# mean       9190.252561
# std        1387.018242
# min           0.000000
# 25%        8790.000000
# 50%        9270.000000
# 75%        9600.000000
# max      102420.000000
# Name: valor, dtype: float64

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(8, 6))
ax = sns.boxplot(x='valor', data=diesel, color="#B452CD")

ax.set_xlabel("Valor Precio")
plt.title('Precio Diesel')
plt.show()

# %%
print("Datos faltantes: ",diesel["valor"].isna().sum())
# Out:
# Datos faltantes:  0

# %% [markdown]
# ### Explicación detallada del paso
# Vemos que en el precio del diesel, tampoco hay valores faltantes pero si una gran cantidad de valores atípicos.
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %%
def detect_outliers_zscore2(data):
    outliers = []
    thres = 2
    mean = np.mean(data)
    std = np.std(data)
    for idx, value in enumerate(data):
        z_score = (value - mean) / std
        if np.abs(z_score) > thres:
            outliers.append(idx)
    
    return outliers

# %%
out=detect_outliers_zscore2(diesel["valor"])
len(out)
# Out:
# 1378

# %% [markdown]
# ### Explicación detallada del paso
# Existen 8614 valores por fuera de 2*RIQ.
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %%
diesel.iloc[out, diesel.columns.get_loc('valor')] = np.nan

# %%
imp = IterativeImputer(max_iter=5, random_state=500)

# Imputar los datos faltantes
diesel_imputado = diesel.copy()
diesel_imputado[['valor']] = imp.fit_transform(diesel[['valor']])

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(8, 6))
ax = sns.boxplot(x='valor', data=diesel_imputado, color="#B452CD")

ax.set_xlabel("Valor Precio")
plt.title('Precio Diesel')
plt.show()

# %% [markdown]
# ### Explicación detallada del paso
# Vemos que en este caso, a diferencia de la gasolina, parece ser que no se detectaron todos los datos, puesto que nuestra función para detectarlos solo está tomando los que están por fuera de 2 veces el RIQ. Pero aun así hubo una gran mejoría con la imputación de los datos más extremos.
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %% [markdown]
# ### Explicación detallada del paso
# ##### **Otros análisis:**
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %%
diesel_bandera = diesel_imputado.groupby('bandera')['valor'].mean().reset_index()
diesel_bandera = diesel_bandera.sort_values(by='valor',ascending=False)
diesel_bandera=diesel_bandera.head(12)

plt.figure(figsize=(12, 6))
sns.barplot(data=diesel_bandera, x='bandera', y='valor', palette='viridis')
plt.xlabel('Bandera')
plt.ylabel('precio por bandera')
plt.xticks(rotation=90)
plt.tight_layout()

# %%
diesel_bandera
# Out:
#                 bandera         valor
# 21  ZAPATA Y VELASQUEZ   10192.590164
# 16              PROXXON   9690.997530
# 4                DISCOM   9607.538594
# 14             PLUS MAS   9583.121113
# 22               ZEUSS    9560.701087
# 10            PETRDECOL   9526.852775
# 8                OCTANO   9523.342944
# 20               TEXACO   9372.438144
# 1                BIOMAX   9359.138161
# 15               PRIMAX   9310.284844
# 2                 BRIO    9299.546644
# 7                  ESSO   9276.560151

# %% [markdown]
# ### Explicación detallada del paso
# Aqui se puede ver que el precio del diesel por bandera no cambia mucho, estas 12 empresas con el diesel mas alto tienen precios cercanos a 9.300.
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %% [markdown]
# ### Explicación detallada del paso
# #### ****Extra****
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %%
extra["valor"].describe()
# Out:
# count     32400.000000
# mean      19132.729537
# std        3089.081601
# min           0.000000
# 25%       19200.000000
# 50%       19720.000000
# 75%       20000.000000
# max      200000.000000
# Name: valor, dtype: float64

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(8, 6))
ax = sns.boxplot(x='valor', data=extra, color="#4234bb")

ax.set_xlabel("Valor Precio")
plt.title('Precio Extra')
plt.show()

# %%
print("Datos faltantes: ",extra["valor"].isna().sum())
# Out:
# Datos faltantes:  0

# %%
out=detect_outliers_zscore2(extra["valor"])
len(out)
# Out:
# 1913

# %%
extra.iloc[out, extra.columns.get_loc('valor')] = np.nan

# %%
imp = IterativeImputer(max_iter=5, random_state=500)

# Imputar los datos faltantes
extra_imputado = extra.copy()
extra_imputado[['valor']] = imp.fit_transform(extra[['valor']])

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(8, 6))
ax = sns.boxplot(x='valor', data=diesel_imputado, color="#4234bb")

ax.set_xlabel("Valor Precio")
plt.title('Precio Extra')
plt.show()

# %% [markdown]
# ### Explicación detallada del paso
# En el caso del combustible extra pasó algo similar a con el diesel, con la imputación mejoró la distribución de la variable, aun cuando se siguen presentando datos atípicos, esto es razonable, puesto que el valor del extra varía en gran manera.
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %%
extra_bandera = extra_imputado.groupby('bandera')['valor'].mean().reset_index()
extra_bandera = extra_bandera.sort_values(by='valor',ascending=True)
extra_bandera=extra_bandera.head(12)

plt.figure(figsize=(12, 6))
sns.barplot(data=extra_bandera, x='bandera', y='valor', palette='viridis')
plt.xlabel('Bandera')
plt.ylabel('precio por bandera')
plt.xticks(rotation=90)
plt.tight_layout()

# %%
extra_bandera
# Out:
#                 bandera         valor
# 0           AYATAWACOOP  13688.111111
# 8             PETRDECOL  17744.115443
# 14              PROXXON  17904.211294
# 19  ZAPATA Y VELASQUEZ   18047.000000
# 5                  ECOS  18358.338476
# 17               TERPEL  19397.597860
# 11            PETROMIL   19400.238843
# 12             PLUS MAS  19466.714286
# 3          COOMULPINORT  19478.387931
# 15                 PUMA  19487.235739
# 4                DISCOM  19517.537147
# 20               ZEUSS   19611.706778

# %% [markdown]
# ### Explicación detallada del paso
# Puesto que el combustible "Extra" es el que tiene el precio promedio mas alto, con la grafica anterior vemos que la bandera "AYATAWACOOP" es el que tiene menor precio promedio 13.600, a diferencia de las otras empresas que sus precios ya rodean los 20.000 pesos colombianos.
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %% [markdown]
# ### Explicación detallada del paso
# ### **Georeferenciación: precio de la gasolina por departamento**
#
# En este paso, estamos abordando los aspectos clave de la operación. La idea es que el lector entienda claramente los objetivos detrás de este código. Se proporciona una descripción más completa de lo que está sucediendo a continuación.

# %%
import geopandas as gpd 
import descartes

# %%
mapa_col = gpd.read_file("datos\COLOMBIA\COLOMBIA.shp")

# %%
gasolina_map=gasolina_imputado.copy()

# %%
dpto_1 = gasolina_map['depto'].str.lower()
dpto_2 = mapa_col['DPTO_CNMBR'].str.lower()

# Encontrar los índices donde los valores de dpto_1 no están en dpto_2
M1 = np.where(~dpto_1.isin(dpto_2))[0]  # Retorna los índices de los valores no coincidentes

# Reemplazar "?" con "ñ" en dpto_2
dpto_2 = dpto_2.str.replace("\?", "ñ", regex=True)

# Reemplazar "archipielago de san andres" con el texto completo en dpto_2
dpto_2 = dpto_2.str.replace("archipielago de san andres", 
                            "archipielago de san andres, santa catalina y providencia", regex=False)

M1 = np.where(~dpto_1.isin(dpto_2))[0] 

# Añadir las columnas 'codigo' con los valores modificados
gasolina_map.loc[:, 'codigo'] = dpto_1
mapa_col.loc[:, 'codigo'] = dpto_2

# %%
gasolina_map["codigo"] = dpto_1
mapa_col["codigo"] = dpto_2

# %%
Datos_tot = pd.merge(mapa_col, gasolina_map , on ='codigo', how = 'outer')
Datos_tot.head(3)
# Out:
#    OBJECTID DPTO_CCDGO  DPTO_NANO_ DPTO_CNMBR                     DPTO_CACTO  \
# 0         1         05        1886  ANTIOQUIA  Constitucion Politica de 1886
# 1         1         05        1886  ANTIOQUIA  Constitucion Politica de 1886
# 2         1         05        1886  ANTIOQUIA  Constitucion Politica de 1886
#
#      DPTO_NAREA DPTO_CSMBL  DPTO_NANO PAIS_PAIS_  SHAPE_Leng  SHAPE_Area  \
# 0  6.306333e+10          3       2005          1   21.137035    5.155783
# 1  6.306333e+10          3       2005          1   21.137035    5.155783
# 2  6.306333e+10          3       2005          1   21.137035    5.155783
#
#                                             geometry     codigo bandera  \
# 0  POLYGON ((-76.40481 8.85708, -76.40440 8.85625...  antioquia  TEXACO
# 1  POLYGON ((-76.40481 8.85708, -76.40440 8.85625...  antioquia  TEXACO
# 2  POLYGON ((-76.40481 8.85708, -76.40440 8.85625...  antioquia  TERPEL
#
#                                          nombreCo        producto  \
# 0                           EDS COMDECOM ABRIAQUI  GASOLINA MOTOR
# 1  ESTACIÓN DE SERVICIO Y MALL SANTA LUCIA S.A.S.  GASOLINA MOTOR
# 2                   ESTACION DE SERVICIO POPALITO  GASOLINA MOTOR
#
#          fecha      depto     munic    valor
# 0  01-Jan-2023  ANTIOQUIA  ABRIAQUÍ  11870.0
# 1  01-Jan-2023  ANTIOQUIA     AMAGÁ  11200.0
# 2  01-Jan-2023  ANTIOQUIA   BARBOSA  10399.0

# %%
datos_unidos2 = (
    Datos_tot
    .groupby(['codigo', 'DPTO_NANO_', 'DPTO_NAREA', 'DPTO_CSMBL', 'DPTO_NANO', 'PAIS_PAIS_', 'SHAPE_Leng', 'SHAPE_Area'], as_index=False)  # Agrupa los datos y evita usar los grupos como índice
    .agg(precio_prom_dpto=('valor', 'mean'))  # Calcula la media de 'valor' y la asigna a 'precio_prom_dpto'
)

# %%
datos_unidos2
# Out:
#                                                codigo  DPTO_NANO_  \
# 0                                            amazonas        1991
# 1                                           antioquia        1886
# 2                                              arauca        1991
# 3   archipielago de san andres, santa catalina y p...        1991
# 4                                           atlantico        1910
# 5                                         bogota d.c.           0
# 6                                             bolivar        1886
# 7                                              boyaca        1886
# 8                                              caldas        1905
# 9                                             caqueta        1981
# 10                                           casanare        1991
# 11                                              cauca        1857
# 12                                              cesar        1967
# 13                                              choco        1947
# 14                                            cordoba        1951
# 15                                       cundinamarca        1886
# 16                                            guainia        1991
# 17                                           guaviare        1991
# 18                                              huila        1905
# 19                                         la guajira        1964
# 20                                          magdalena           0
# 21                                               meta        1959
# 22                                             nariño        1904
# 23                                 norte de santander        1910
# 24                                           putumayo        1991
# 25                                            quindio        1966
# 26                                          risaralda        1966
# 27                                          santander        1910
# 28                                              sucre        1966
# 29                                             tolima        1909
# 30                                    valle del cauca        1910
# 31                                             vaupes        1991
# 32                                            vichada        1991
#
#       DPTO_NAREA DPTO_CSMBL  DPTO_NANO PAIS_PAIS_  SHAPE_Leng  SHAPE_Area  \
# 0   1.100465e+11          3       2005         28   24.747842    8.921607
# 1   6.306333e+10          3       2005          1   21.137035    5.155783
# 2   2.380556e+10          3       2005         25    9.162939    1.940327
# 3   4.960214e+04          3       2005         12    0.650698    0.004064
# 4   3.326730e+09          3       2005          2    2.461077    0.274825
# 5   1.633209e+09          3       2005          3    3.731288    0.133045
# 6   2.666559e+10          3       2005          4   15.706980    2.191055
# 7   2.307705e+10          3       2005          5   15.280968    1.883315
# 8   7.415933e+09          3       2005          6    6.614200    0.604712
# 9   9.007665e+10          3       2005          7   19.850907    7.316017
# 10  4.448400e+10          3       2005         26   11.830742    3.622186
# 11  3.064331e+10          3       2005          8   13.352092    2.485633
# 12  2.228367e+10          3       2005          9   12.597031    1.834978
# 13  4.757908e+10          3       2005         12   19.085028    3.876418
# 14  2.504194e+10          3       2005         10    8.982757    2.053760
# 15  2.236838e+10          3       2005         11   12.960193    1.823363
# 16  7.156745e+10          3       2005         29   19.493315    5.769826
# 17  5.545392e+10          3       2005         30   18.739054    4.501348
# 18  1.871102e+10          3       2005         13    9.803136    1.520385
# 19  2.067067e+10          3       2005         14   10.168370    1.711062
# 20  2.320573e+10          3       2005         15   10.747550    1.914917
# 21  8.548555e+10          3       2005         16   17.455890    6.951611
# 22  3.164991e+10          3       2005         17   10.819582    2.560667
# 23  2.202302e+10          3       2005         18   11.128765    1.805850
# 24  2.589376e+10          3       2005         27   12.672464    2.101163
# 25  1.935384e+09          3       2005         19    2.507765    0.157564
# 26  3.978381e+09          3       2005         20    5.135623    0.324123
# 27  3.059683e+10          3       2005         21   11.452211    2.501891
# 28  1.070915e+10          3       2005         22    8.133088    0.880406
# 29  2.398336e+10          3       2005         23    9.315385    1.952249
# 30  2.126936e+10          3       2005         24   10.439368    1.728411
# 31  5.354358e+10          3       2005         31   19.242591    4.333330
# 32  1.000144e+11          3       2005         32   17.181693    8.096236
#
#     precio_prom_dpto
# 0       15236.346154
# 1       13093.399409
# 2       12779.423077
# 3       14224.962963
# 4       12350.908540
# 5       12574.697156
# 6       12633.533408
# 7       13239.346864
# 8       13045.504036
# 9       13208.076658
# 10      13099.819985
# 11      12884.249272
# 12      10787.837878
# 13      13692.445074
# 14      13072.453127
# 15      12937.432114
# 16      15053.919118
# 17      14286.956747
# 18      12961.591182
# 19      13239.689811
# 20      12639.437850
# 21      13230.244919
# 22      11240.606136
# 23      12191.534647
# 24      12457.861062
# 25      12821.541063
# 26      12794.187330
# 27      12413.302259
# 28      12692.576836
# 29      12801.220516
# 30      12695.004844
# 31      18459.177215
# 32      13242.754420

# %%
mapa_col['promedio_precio'] = datos_unidos2["precio_prom_dpto"]

mapa_col
# Out:
#     OBJECTID DPTO_CCDGO  DPTO_NANO_                  DPTO_CNMBR  \
# 0          1         05        1886                   ANTIOQUIA
# 1          2         08        1910                   ATLANTICO
# 2          3         11           0                 BOGOTA D.C.
# 3          4         13        1886                     BOLIVAR
# 4          5         15        1886                      BOYACA
# 5          6         17        1905                      CALDAS
# 6          7         18        1981                     CAQUETA
# 7          8         19        1857                       CAUCA
# 8          9         20        1967                       CESAR
# 9         10         23        1951                     CORDOBA
# 10        11         25        1886                CUNDINAMARCA
# 11        12         27        1947                       CHOCO
# 12        13         41        1905                       HUILA
# 13        14         44        1964                  LA GUAJIRA
# 14        15         47           0                   MAGDALENA
# 15        16         50        1959                        META
# 16        17         52        1904                      NARI?O
# 17        18         54        1910          NORTE DE SANTANDER
# 18        19         63        1966                     QUINDIO
# 19        20         66        1966                   RISARALDA
# 20        21         68        1910                   SANTANDER
# 21        22         70        1966                       SUCRE
# 22        23         73        1909                      TOLIMA
# 23        24         76        1910             VALLE DEL CAUCA
# 24        25         81        1991                      ARAUCA
# 25        26         85        1991                    CASANARE
# 26        27         86        1991                    PUTUMAYO
# 27        28         91        1991                    AMAZONAS
# 28        29         94        1991                     GUAINIA
# 29        30         95        1991                    GUAVIARE
# 30        31         97        1991                      VAUPES
# 31        32         99        1991                     VICHADA
# 32        33         88        1991  ARCHIPIELAGO DE SAN ANDRES
#
#                                            DPTO_CACTO    DPTO_NAREA  \
# 0                       Constitucion Politica de 1886  6.306333e+10
# 1                                      Ley 21 de 1910  3.326730e+09
# 2                                                None  1.633209e+09
# 3                       Constitucion Politica de 1886  2.666559e+10
# 4                       Constitucion Politica de 1886  2.307705e+10
# 5                                 11 de Abril de 1905  7.415933e+09
# 6                  Ley 78 del 29 de Diciembre de 1981  9.007665e+10
# 7                                 15 de junio de 1857  3.064331e+10
# 8                         Ley 25  21 de junio de 1967  2.228367e+10
# 9                   Ley 9 del 18 de Diciembre de 1951  2.504194e+10
# 10                      Constitucion Politica de 1886  2.236838e+10
# 11                  Ley 13 del 3 de Noviembre de 1947  4.757908e+10
# 12                                     Ley 46 de 1905  1.871102e+10
# 13     Acto Legislativo No. 1 de Diciembre 28 de 1964  2.067067e+10
# 14                                               None  2.320573e+10
# 15                Ley 118 del 16 de Diciembre de 1959  8.548555e+10
# 16                                      Ley 1 de 1904  3.164991e+10
# 17                                     Ley 25 de 1910  2.202302e+10
# 18                                   Ley 2 TM de 1966  1.935384e+09
# 19                  Ley 70 del 1 de Diciembre de 1966  3.978381e+09
# 20                         Ley 25 14 de Julio de 1910  3.059683e+10
# 21                     Ley 47 del 8 de Agosto de 1966  1.070915e+10
# 22                        Ley 65 de Noviembre de 1909  2.398336e+10
# 23              Decreto No 340 de 16 de Abril de 1910  2.126936e+10
# 24           5 de Julio Constitucion Politica de 1991  2.380556e+10
# 25           5 de Julio Constitucion Politica de 1991  4.448400e+10
# 26         Articulo 309 Constitucion Politica de 1991  2.589376e+10
# 27  Decreto 2274 del 4 de Octubre de la Constituci...  1.100465e+11
# 28         Articulo 309 Constitucion Politica de 1991  7.156745e+10
# 29           5 de Julio Constitucion Politica de 1991  5.545392e+10
# 30         Articulo 309 Constitucion Politica de 1991  5.354358e+10
# 31           5 de Julio Constitucion Politica de 1991  1.000144e+11
# 32        ArtÃ­culo 310 Constitucion Politica de 1991  4.960214e+04
#
#    DPTO_CSMBL  DPTO_NANO PAIS_PAIS_  SHAPE_Leng  SHAPE_Area  \
# 0           3       2005          1   21.137035    5.155783
# 1           3       2005          2    2.461077    0.274825
# 2           3       2005          3    3.731288    0.133045
# 3           3       2005          4   15.706980    2.191055
# 4           3       2005          5   15.280968    1.883315
# 5           3       2005          6    6.614200    0.604712
# 6           3       2005          7   19.850907    7.316017
# 7           3       2005          8   13.352092    2.485633
# 8           3       2005          9   12.597031    1.834978
# 9           3       2005         10    8.982757    2.053760
# 10          3       2005         11   12.960193    1.823363
# 11          3       2005         12   19.085028    3.876418
# 12          3       2005         13    9.803136    1.520385
# 13          3       2005         14   10.168370    1.711062
# 14          3       2005         15   10.747550    1.914917
# 15          3       2005         16   17.455890    6.951611
# 16          3       2005         17   10.819582    2.560667
# 17          3       2005         18   11.128765    1.805850
# 18          3       2005         19    2.507765    0.157564
# 19          3       2005         20    5.135623    0.324123
# 20          3       2005         21   11.452211    2.501891
# 21          3       2005         22    8.133088    0.880406
# 22          3       2005         23    9.315385    1.952249
# 23          3       2005         24   10.439368    1.728411
# 24          3       2005         25    9.162939    1.940327
# 25          3       2005         26   11.830742    3.622186
# 26          3       2005         27   12.672464    2.101163
# 27          3       2005         28   24.747842    8.921607
# 28          3       2005         29   19.493315    5.769826
# 29          3       2005         30   18.739054    4.501348
# 30          3       2005         31   19.242591    4.333330
# 31          3       2005         32   17.181693    8.096236
# 32          3       2005         12    0.650698    0.004064
#
#                                              geometry  \
# 0   POLYGON ((-76.40481 8.85708, -76.40440 8.85625...
# 1   POLYGON ((-74.82969 11.04992, -74.82937 11.049...
# 2   POLYGON ((-74.07274 4.83565, -74.07217 4.83505...
# 3   MULTIPOLYGON (((-75.24966 10.79804, -75.24926 ...
# 4   POLYGON ((-72.01129 7.00944, -72.01029 7.00912...
# 5   POLYGON ((-74.67118 5.77127, -74.67112 5.77115...
# 6   POLYGON ((-74.91094 2.96445, -74.90768 2.96367...
# 7   POLYGON ((-76.45841 3.32857, -76.45819 3.32857...
# 8   POLYGON ((-73.45957 10.86878, -73.45905 10.868...
# 9   POLYGON ((-75.92261 9.43892, -75.92209 9.43846...
# 10  POLYGON ((-73.05116 4.73500, -73.05862 4.68673...
# 11  POLYGON ((-77.34700 8.64468, -77.34604 8.64467...
# 12  POLYGON ((-74.52051 3.82768, -74.51933 3.82763...
# 13  POLYGON ((-71.66688 12.45820, -71.66673 12.458...
# 14  POLYGON ((-74.04415 11.34911, -74.04397 11.349...
# 15  POLYGON ((-71.07750 4.92462, -71.07753 4.87697...
# 16  POLYGON ((-78.00558 2.68956, -78.00547 2.68956...
# 17  POLYGON ((-73.00472 9.28011, -73.00520 9.27873...
# 18  POLYGON ((-75.70240 4.72112, -75.70211 4.72063...
# 19  POLYGON ((-75.99569 5.52893, -75.99512 5.52748...
# 20  POLYGON ((-73.77891 8.13972, -73.77701 8.14216...
# 21  POLYGON ((-75.53687 10.06265, -75.54466 10.045...
# 22  POLYGON ((-74.73360 5.28577, -74.73033 5.27905...
# 23  POLYGON ((-76.06306 5.01515, -76.06240 5.01510...
# 24  POLYGON ((-70.67671 7.09263, -70.67666 7.09251...
# 25  POLYGON ((-72.36091 6.28102, -72.36093 6.28101...
# 26  POLYGON ((-76.89592 1.51027, -76.89606 1.50996...
# 27  POLYGON ((-71.29212 0.06821, -71.28829 0.06762...
# 28  POLYGON ((-67.68356 3.90772, -67.67950 3.90308...
# 29  POLYGON ((-71.28567 2.87055, -71.28500 2.87051...
# 30  POLYGON ((-70.10256 2.07311, -70.10401 2.07224...
# 31  POLYGON ((-67.70980 4.03949, -67.71273 4.03756...
# 32  MULTIPOLYGON (((-81.70353 12.59404, -81.70342 ...
#
#                                                codigo  promedio_precio
# 0                                           antioquia     15236.346154
# 1                                           atlantico     13093.399409
# 2                                         bogota d.c.     12779.423077
# 3                                             bolivar     14224.962963
# 4                                              boyaca     12350.908540
# 5                                              caldas     12574.697156
# 6                                             caqueta     12633.533408
# 7                                               cauca     13239.346864
# 8                                               cesar     13045.504036
# 9                                             cordoba     13208.076658
# 10                                       cundinamarca     13099.819985
# 11                                              choco     12884.249272
# 12                                              huila     10787.837878
# 13                                         la guajira     13692.445074
# 14                                          magdalena     13072.453127
# 15                                               meta     12937.432114
# 16                                             nariño     15053.919118
# 17                                 norte de santander     14286.956747
# 18                                            quindio     12961.591182
# 19                                          risaralda     13239.689811
# 20                                          santander     12639.437850
# 21                                              sucre     13230.244919
# 22                                             tolima     11240.606136
# 23                                    valle del cauca     12191.534647
# 24                                             arauca     12457.861062
# 25                                           casanare     12821.541063
# 26                                           putumayo     12794.187330
# 27                                           amazonas     12413.302259
# 28                                            guainia     12692.576836
# 29                                           guaviare     12801.220516
# 30                                             vaupes     12695.004844
# 31                                            vichada     18459.177215
# 32  archipielago de san andres, santa catalina y p...     13242.754420

# %%
mapa_col.plot(column="promedio_precio",figsize=(30,18), legend=True, edgecolor="black",cmap="Reds")

for index,row in mapa_col.iterrows():
    xy=row['geometry'].centroid.coords[:]
    xytext=row['geometry'].centroid.coords[:]
    plt.annotate(row['DPTO_CNMBR'],xy=xy[0], xytext=xytext[0],  horizontalalignment='center',verticalalignment='center',fontsize=8)
    plt.axis('off')
